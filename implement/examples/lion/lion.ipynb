# %%
import sys, os
_base = os.path.abspath(os.path.join(os.getcwd(), '..', '..'))
sys.path.insert(0, os.path.join(_base, 'kepler-mapper'))
sys.path.insert(0, os.path.join(_base, 'mealpy'))
sys.path.insert(0, os.path.abspath(os.path.join(os.getcwd(), '..')))
from smapper_utils import run_optimization, draw_graph, SEED, EPOCH, POP_SIZE

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import networkx as nx
import kmapper as km
import kmapper.evaluate as evaluate
from sklearn import cluster
import sklearn

# %%
data = pd.read_csv('lion-reference.csv').to_numpy()

# %%
mapper = km.KeplerMapper(verbose=0)
projected_data = mapper.fit_transform(data)

# %%
def objective_function(X):
    n = int(round(float(X[0])))
    a = float(X[1])
    try:
        cover = km.Cover(n_cubes=n, perc_overlap=a)
        graph = mapper.map(projected_data, data,
                           clusterer=cluster.DBSCAN(eps=0.1, min_samples=5), cover=cover)
        tsc = evaluate.compute_SC_adj(data, projected_data, graph, cover,
                                      type='k', cluster=cluster.DBSCAN(eps=0.1, min_samples=5))
        return -tsc
    except Exception:
        return 3.0

from mealpy import FloatVar
problem = {
    "obj_func": objective_function,
    "bounds": [FloatVar(lb=9, ub=25, name="n"), FloatVar(lb=0.1, ub=0.7, name="a")],
    "minmax": "min",
}
results = run_optimization(problem, 'results_output_lion.txt')
# Out:
# 100%|██████████| 100/100 [00:05<00:00, 17.07it/s]
# 2026/05/05 01:03:01 AM, INFO, mealpy.swarm_based.PSO.OriginalPSO: Solving single objective optimization problem.
# SC:-0.11835942989428762
# SC_norm:0.4408202850528562
# TSR:0.5161290322580645
# SC_adj:0.47847465865546035
# 100%|██████████| 100/100 [00:03<00:00, 27.52it/s]
# SC:-0.04078153556861427
# SC_norm:0.47960923221569285
# TSR:0.5
# SC_adj:0.4898046161078464
# 100%|██████████| 100/100 [00:06<00:00, 14.92it/s]
# SC:-0.12857579060566865
# SC_norm:0.4357121046971657
# TSR:0.6470588235294118
# SC_adj:0.5413854641132887
# 100%|██████████| 100/100 [00:05<00:00, 19.42it/s]
# SC:-0.08889468559882749
# SC_norm:0.45555265720058624
# TSR:0.37037037037037035
# SC_adj:0.4129615137854783
# 100%|██████████| 100/100 [00:02<00:00, 35.53it/s]
# SC:0.0782171842599805
# SC_norm:0.5391085921299903
# TSR:1.0
# SC_adj:0.7695542960649951
# 100%|██████████| 100/100 [00:08<00:00, 11.98it/s]
# SC:-0.15605529237003157
# SC_norm:0.4219723538149842
# ...

# %%
n, a = 9, 0.1
cover = km.Cover(n_cubes=n, perc_overlap=a)
graph = mapper.map(projected_data, data, clusterer=cluster.DBSCAN(eps=0.1, min_samples=5), cover=cover)
draw_graph(graph, projected_data, 'lion.png')
evaluate.compute_SC_adj(data, projected_data, graph, cover,
                        type='k', cluster=cluster.DBSCAN(eps=0.1, min_samples=5))
# Out:
# 100%|██████████| 100/100 [00:02<00:00, 33.35it/s]
# SC:0.1260631516046
# SC_norm:0.5630315758023
# TSR:1.0
# SC_adj:0.7815157879011501
# 0.7815157879011501

# %% [markdown]
# # Mapper

# %%
n, a = 12, 0.2
cover = km.Cover(n_cubes=n, perc_overlap=a)
graph = mapper.map(projected_data, data, clusterer=cluster.DBSCAN(eps=0.1, min_samples=5), cover=cover)
draw_graph(graph, projected_data, 'lion.png')
evaluate.compute_SC_adj(data, projected_data, graph, cover,
                        type='k', cluster=cluster.DBSCAN(eps=0.1, min_samples=5))
# Out:
# 100%|██████████| 100/100 [00:02<00:00, 33.63it/s]
# SC:0.0275799434647643
# SC_norm:0.5137899717323822
# TSR:0.5
# SC_adj:0.5068949858661911
# 0.5068949858661911

# %% [markdown]
# # D-Mapper

# %%
mapper_d = km.D_Mapper(verbose=0)
n, a = 9, 0.05
cover_d = km.D_Cover(n_cubes=n, alpha=a, max_iter=100000, n_init=10, verbose=0)
graphD = mapper_d.map(projected_data, data,
                      clusterer=cluster.DBSCAN(eps=0.1, min_samples=5), cover=cover_d)
draw_graph(graphD, projected_data, 'liong.png')
evaluate.compute_SC_adj(data, projected_data, graphD,
                        km.D_Cover(n_cubes=n, alpha=a, max_iter=100000, n_init=10, verbose=0),
                        type='d', cluster=cluster.DBSCAN(eps=0.1, min_samples=5))
# Out:
# 100%|██████████| 100/100 [00:17<00:00,  5.75it/s]
# SC:0.05045530562
# SC_norm:0.52522765281
# TSR:0.6666666666666666
# SC_adj:0.5959471597383332
# 0.5959471597383332
