# %%
import sys, os
_base = os.path.abspath(os.path.join(os.getcwd(), '..', '..'))
sys.path.insert(0, os.path.join(_base, 'kepler-mapper'))
sys.path.insert(0, os.path.join(_base, 'mealpy'))
sys.path.insert(0, os.path.abspath(os.path.join(os.getcwd(), '..')))
from smapper_utils import run_optimization, draw_graph, SEED, EPOCH, POP_SIZE

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import networkx as nx
import kmapper as km
import kmapper.evaluate as evaluate
from dyneusr.datasets import make_trefoil
from sklearn import cluster

# %%
trefoil_data = make_trefoil(size=100)
data = trefoil_data.data
mapper = km.KeplerMapper(verbose=0)
projected_data = mapper.fit_transform(data, projection=[0])

# %%
# w1, w2 = 0.9, 0.1

# def objective_function(X, w1=w1, w2=w2):
#     n = int(round(float(X[0])))
#     a = float(X[1])
#     try:
#         cover = km.Cover(n_cubes=n, perc_overlap=a)
#         graph = mapper.map(projected_data, data, cover=cover)
#         tsc = evaluate.compute_SC_adj(
#             data,
#             projected_data,
#             graph,
#             cover,
#             type='k',
#             w1=w1,
#             w2=w2,
#         )
#         return -tsc
#     except Exception:
#         return 3.0

# from mealpy import FloatVar
# problem = {
#     "obj_func": objective_function,
#     "bounds": [FloatVar(lb=5, ub=25, name="n"), FloatVar(lb=0.1, ub=0.7, name="a")],
#     "minmax": "min",
# }

# output_file = f"results_output_trefoil_w1_{w1:.1f}_w2_{w2:.1f}.txt"
# results = run_optimization(problem, output_file)
# results

# %% [markdown]
# # Weight Sensitivity — S-Mapper Results

# %% [markdown]
# ## w1=0.0, w2=1.0

# %%
# GWO — w1=0.0, w2=1.0 | n=5, a=0.323, TSC=0.5
n, a = 5, 0.323
cover = km.Cover(n_cubes=n, perc_overlap=a)
graph = mapper.map(projected_data, data, cover=cover)
draw_graph(graph, projected_data, '1.png')
evaluate.compute_SC_adj(data, projected_data, graph, cover, type='k', w1=0.0, w2=1.0)
# Out:
# 100%|██████████| 100/100 [00:00<00:00, 441.23it/s]
# SC:0.055510257747
# SC_norm:0.5277551288735
# TSR:0.5
# SC_adj:0.5
# 0.5

# %% [markdown]
# ## w1=0.1, w2=0.9

# %%
# GWO — w1=0.1, w2=0.9 | n=6, a=0.179, TSC=0.5072
n, a = 6, 0.179
cover = km.Cover(n_cubes=n, perc_overlap=a)
graph = mapper.map(projected_data, data, cover=cover)
draw_graph(graph, projected_data, '2.png')
evaluate.compute_SC_adj(data, projected_data, graph, cover, type='k', w1=0.1, w2=0.9)
# Out:
# 100%|██████████| 100/100 [00:00<00:00, 386.35it/s]
# SC:0.1437861686184895
# SC_norm:0.5718930843092448
# TSR:0.5
# SC_adj:0.5071893084309245
# 0.5071893084309245

# %% [markdown]
# ## w1=0.2, w2=0.8

# %%
# GWO — w1=0.2, w2=0.8 | n=6, a=0.176, TSC=0.5144
n, a = 6, 0.176
cover = km.Cover(n_cubes=n, perc_overlap=a)
graph = mapper.map(projected_data, data, cover=cover)
draw_graph(graph, projected_data, '3.png')
evaluate.compute_SC_adj(data, projected_data, graph, cover, type='k', w1=0.2, w2=0.8)
# Out:
# 100%|██████████| 100/100 [00:00<00:00, 325.08it/s]
# SC:0.1437861686184895
# SC_norm:0.5718930843092448
# TSR:0.5
# SC_adj:0.5143786168618489
# 0.5143786168618489

# %% [markdown]
# ## w1=0.3, w2=0.7

# %%
# GWO — w1=0.3, w2=0.7 | n=6, a=0.181, TSC=0.5216
n, a = 6, 0.181
cover = km.Cover(n_cubes=n, perc_overlap=a)
graph = mapper.map(projected_data, data, cover=cover)
draw_graph(graph, projected_data, '4.png')
evaluate.compute_SC_adj(data, projected_data, graph, cover, type='k', w1=0.3, w2=0.7)
# Out:
# 100%|██████████| 100/100 [00:00<00:00, 329.64it/s]
# SC:0.1437861686184895
# SC_norm:0.5718930843092448
# TSR:0.5
# SC_adj:0.5215679252927734
# 0.5215679252927734

# %% [markdown]
# ## w1=0.4, w2=0.6

# %%
# GWO — w1=0.4, w2=0.6 | n=6, a=0.174, TSC=0.5288
n, a = 6, 0.174
cover = km.Cover(n_cubes=n, perc_overlap=a)
graph = mapper.map(projected_data, data, cover=cover)
draw_graph(graph, projected_data, '5.png')
evaluate.compute_SC_adj(data, projected_data, graph, cover, type='k', w1=0.4, w2=0.6)
# Out:
# 100%|██████████| 100/100 [00:00<00:00, 346.62it/s]
# SC:0.1437861686184895
# SC_norm:0.5718930843092448
# TSR:0.5
# SC_adj:0.5287572337236979
# 0.5287572337236979

# %% [markdown]
# ## w1=0.5, w2=0.5

# %%
# GWO — w1=0.5, w2=0.5 | n=6, a=0.177, TSC=0.5359
n, a = 6, 0.177
cover = km.Cover(n_cubes=n, perc_overlap=a)
graph = mapper.map(projected_data, data, cover=cover)
draw_graph(graph, projected_data, '6.png')
evaluate.compute_SC_adj(data, projected_data, graph, cover, type='k', w1=0.5, w2=0.5)
# Out:
# 100%|██████████| 100/100 [00:00<00:00, 271.12it/s]
# SC:0.1437861686184895
# SC_norm:0.5718930843092448
# TSR:0.5
# SC_adj:0.5359465421546223
# 0.5359465421546223

# %% [markdown]
# ## w1=0.6, w2=0.4

# %%
# GWO — w1=0.6, w2=0.4 | n=6, a=0.18, TSC=0.5431
n, a = 6, 0.18
cover = km.Cover(n_cubes=n, perc_overlap=a)
graph = mapper.map(projected_data, data, cover=cover)
draw_graph(graph, projected_data, '7.png')
evaluate.compute_SC_adj(data, projected_data, graph, cover, type='k', w1=0.6, w2=0.4)
# Out:
# 100%|██████████| 100/100 [00:00<00:00, 349.84it/s]
# SC:0.1437861686184895
# SC_norm:0.5718930843092448
# TSR:0.5
# SC_adj:0.5431358505855468
# 0.5431358505855468

# %% [markdown]
# ## w1=0.7, w2=0.3

# %%
# PSO — w1=0.7, w2=0.3 | n=20, a=0.167, TSC=0.6606
n, a = 20, 0.167
cover = km.Cover(n_cubes=n, perc_overlap=a)
graph = mapper.map(projected_data, data, cover=cover)
draw_graph(graph, projected_data, '8.png')
evaluate.compute_SC_adj(data, projected_data, graph, cover, type='k', w1=0.7, w2=0.3)
# Out:
# 100%|██████████| 100/100 [00:00<00:00, 179.88it/s]
# SC:0.458883
# SC_norm:0.7294415
# TSR:0.0
# SC_adj:0.5106090499999999
# 0.5106090499999999

# %% [markdown]
# ## w1=0.8, w2=0.2

# %%
# GWO — w1=0.8, w2=0.2 | n=25, a=0.1, TSC=0.7011
n, a = 25, 0.1
cover = km.Cover(n_cubes=n, perc_overlap=a)
graph = mapper.map(projected_data, data, cover=cover)
draw_graph(graph, projected_data, '9.png')
evaluate.compute_SC_adj(data, projected_data, graph, cover, type='k', w1=0.8, w2=0.2)
# Out:
# 100%|██████████| 100/100 [00:00<00:00, 188.47it/s]
# SC:0.7528
# SC_norm:0.8764000000000001
# TSR:0.0
# SC_adj:0.7011200000000001
# 0.7011200000000001

# %% [markdown]
# ## w1=0.9, w2=0.1

# %%
# GWO — w1=0.9, w2=0.1 | n=25, a=0.1, TSC=0.7888
n, a = 25, 0.1
cover = km.Cover(n_cubes=n, perc_overlap=a)
graph = mapper.map(projected_data, data, cover=cover)
draw_graph(graph, projected_data, '10.png')
evaluate.compute_SC_adj(data, projected_data, graph, cover, type='k', w1=0.9, w2=0.1)
# Out:
# 100%|██████████| 100/100 [00:00<00:00, 188.47it/s]
# SC:0.7528
# SC_norm:0.8764000000000001
# TSR:0.0
# SC_adj:0.7887600000000001
# 0.7887600000000001

# %% [markdown]
# ## w1=1.0, w2=0.0

# %%
# GWO — w1=1.0, w2=0.0 | n=25, a=0.1, TSC=0.8764
n, a = 25, 0.1
cover = km.Cover(n_cubes=n, perc_overlap=a)
graph = mapper.map(projected_data, data, cover=cover)
draw_graph(graph, projected_data, '11.png')
evaluate.compute_SC_adj(data, projected_data, graph, cover, type='k', w1=1.0, w2=0.0)
# Out:
# 100%|██████████| 100/100 [00:00<00:00, 180.06it/s]
# SC:0.7528
# SC_norm:0.8764000000000001
# TSR:0.0
# SC_adj:0.8764000000000001
# 0.8764000000000001
